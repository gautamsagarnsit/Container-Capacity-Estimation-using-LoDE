# %%
import pandas as pd
import numpy as np
import cv2

# %%
cols=['id','container id','scenario','background','illumination','width at the top','width at the bottom','height','depth','container capacity']
df=pd.read_csv('dataset/annotation/annotations.csv')
df=df[cols]
df=df.set_index('id')
df.head()
# Out:
#    id  container id  scenario  background  illumination  width at the top  \
# 0   0             2         2           1             0              69.0
# 1   1             7         0           0             0             193.0
# 2   2             2         0           1             0              69.0
# 3   3             8         0           1             0             135.0
# 4   4             4         1           1             0              88.0
#
#    width at the bottom  height  depth  container capacity  container mass  \
# 0                 42.0    72.0   -1.0             185.000             2.0
# 1                193.0   241.0   69.0            3209.397            59.0
# 2                 42.0    72.0   -1.0             185.000             2.0
# 3                135.0   164.0   56.0            1239.840            31.0
# 4                 56.0    91.0   -1.0             296.000            86.0
#
#    filling type  filling level  filling density  filling mass  object mass  \
# 0             2              1             0.82          76.0         78.0
# 1             0              0             0.00           0.0         59.0
# 2             3              1             1.00          93.0         95.0
# 3             0              0             0.00           0.0         31.0
# 4             1              1             0.34          45.0        131.0
#
#    handover starting frame  handover start timestamp  handover hand
# 0                       -1                        -1             -1
# 1                       -1                        -1             -1
# 2                       -1                        -1             -1
# 3                       -1                        -1             -1
# 4                       -1                        -1             -1

# %%
indexes=[]
for i in df['container id'].unique():
    temp_df=df[df['container id']==i]
    temp_df=temp_df.drop_duplicates()
    indexes.append(temp_df.index.values)
indexes=list(np.concatenate(indexes).flat)
indexes
# Out:
# [0,
#  2,
#  9,
#  15,
#  29,
#  37,
#  114,
#  124,
#  151,
#  164,
#  212,
#  238,
#  1,
#  5,
#  8,
#  34,
#  48,
#  57,
#  95,
#  103,
#  112,
#  143,
#  158,
#  196,
#  3,
#  14,
#  19,
#  32,
#  38,
#  46,
#  61,
#  101,
#  129,
#  165,
#  169,
#  200,
#  4,
#  21,
#  41,
#  42,
#  50,
#  53,
#  58,
#  83,
#  98,
#  121,
#  190,
#  254,
#  6,
#  10,
#  12,
#  22,
#  30,
#  55,
#  76,
#  99,
#  118,
#  132,
#  160,
#  232,
#  7,
#  43,
#  49,
#  54,
#  65,
#  67,
#  72,
#  74,
#  84,
#  152,
#  192,
#  252,
#  11,
#  23,
#  26,
#  31,
#  33,
#  35,
#  87,
#  96,
#  130,
#  131,
#  185,
#  209,
#  13,
#  20,
#  25,
#  27,
#  62,
#  77,
#  117,
#  122,
#  125,
#  217,
#  222,
#  301,
#  17,
#  24,
#  28,
#  47,
#  51,
#  63,
#  97,
#  123,
#  148,
#  214,
#  270,
#  311]

# %%
len(indexes)
# Out:
# 108

# %%
import os

# %%
try:      
    path=os.path.join(os.getcwd(),'trainset\\rgb_images')
    if not os.path.exists(path):
        os.makedirs(path)
except OSError:
    print ('Error: Creating directory of data')

# %%
video_id=500
view=1
object_id=int(df.iloc[video_id]['container id'])
lighting=int(df.iloc[video_id].illumination)
background=int(df.iloc[video_id].background)

# %%
s=f'{video_id:06d}'+'.mp4'
video_path=os.path.join(os.getcwd(),f'trainset\\view{view:01d}\\rgb\\'+s)
print("Fetching Video from path:",video_path)
cam = cv2.VideoCapture(video_path)
length = int(cam.get(cv2.CAP_PROP_FRAME_COUNT))
print('Total Length',length)
frames=[0,int(0.1*length),int(0.4*length),int(0.6*length),int(0.99*length)]
#currentframe = 1
for idx in range(length):
    # reading from frame
    ret,frame = cam.read()  
    if idx in frames:
        if ret:
            # if video is still left continue creating images
            file_name=f'id{object_id:01d}_f{idx+1:01d}_l{lighting:01d}_b{background:01d}_c{view:01d}_rgb.png'
            name = os.path.join(path,file_name)
            print ('Creating...' + name)  
            # writing the extracted images
            cv2.imwrite(name, frame)

            # increasing counter so that it will
            # show how many frames are created
            #currentframe += 1
        else:
            break
  
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Fetching Video from path: D:\Gautam\Projects\CORSMAL\code\trainset\view1\rgb\000500.mp4
# Total Length 260
# Creating...D:\Gautam\Projects\CORSMAL\code\trainset\rgb_images\id1_f1_l0_b0_c1_rgb.png
# Creating...D:\Gautam\Projects\CORSMAL\code\trainset\rgb_images\id1_f27_l0_b0_c1_rgb.png
# Creating...D:\Gautam\Projects\CORSMAL\code\trainset\rgb_images\id1_f105_l0_b0_c1_rgb.png
# Creating...D:\Gautam\Projects\CORSMAL\code\trainset\rgb_images\id1_f157_l0_b0_c1_rgb.png
# Creating...D:\Gautam\Projects\CORSMAL\code\trainset\rgb_images\id1_f258_l0_b0_c1_rgb.png

# %%
from tqdm import tqdm

cols=['id','container id','scenario','background','illumination','width at the top','width at the bottom','height','depth','container capacity']
df=pd.read_csv('./dataset/annotation/annotations.csv')
df=df[cols]
df=df.set_index('id')

train_indexes=[]
test_indexes=[]
indexes=[]

# Divide into train and test test here

for i in df['container id'].unique():
    if i not in [3,6,9]:
        temp_df=df[df['container id']==i]
        temp_df=temp_df.drop_duplicates()
        train_indexes.append(temp_df.index.values)
        indexes.append(temp_df.index.values)
    
for i in [3,6,9]:
    temp_df=df[df['container id']==i]
    temp_df=temp_df.drop_duplicates()
    test_indexes.append(temp_df.index.values)
    indexes.append(temp_df.index.values)
    
indexes=list(np.concatenate(indexes).flat)
train_indexes=list(np.concatenate(train_indexes).flat)
test_indexes=list(np.concatenate(test_indexes).flat)


try:
    path=os.path.join(os.getcwd(),'trainset\\train_images_1')
    if not os.path.exists(path):
        os.makedirs(path)
except OSError:
    print ('Error: Creating directory of data')

for video_id in tqdm(indexes,total=len(indexes)): 
    for view in range(2,3):
        currentframe=1
        object_id=int(df.iloc[video_id]['container id'])
        lighting=int(df.iloc[video_id].illumination)
        background=int(df.iloc[video_id].background)
        s=f'{video_id:06d}'+'.mp4'
        video_path=os.path.join(os.getcwd(),f'trainset\\view{view:01d}\\rgb\\'+s)
        cam = cv2.VideoCapture(video_path)
        length = int(cam.get(cv2.CAP_PROP_FRAME_COUNT))
        #print('Total Length',length)
        frames=[0,int(0.1*length),int(0.4*length),int(0.6*length),int(0.99*length)]
        for idx in range(length):
            ret,frame = cam.read()  
            if idx in frames:
                if ret:
                    file_name=f'id{object_id:01d}_f{currentframe:01d}_l{lighting:01d}_b{background:01d}_c{view:01d}_rgb.png'
                    name = os.path.join(path,file_name)
                    #print ('Creating...' + name)  
                    cv2.imwrite(name, frame)
                    currentframe+=1
                else:
                    break
        cam.release()
        cv2.destroyAllWindows()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 108/108 [12:14<00:00,  6.80s/it]

# %%
frames
# Out:
# [0, 9, 39, 59, 98]

# %%
for object_id in range(1,10):
    for currentframe in range(1,6):
        for lighting in range(2):
            for background in range(2):
                for view in range(2,3):
                    file_name_exist=f'id{object_id:01d}_f{currentframe:01d}_l{lighting:01d}_b{background:01d}_c{view:01d}_rgb.png'
                    if not os.path.exists(os.path.join(path,file_name_exist)):
                        print("File Does Not exist:",file_name_exist)
